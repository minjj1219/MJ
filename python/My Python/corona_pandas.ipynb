# %%
import pandas as pd

corona_df = pd.read_csv('./corona.csv')
corona_df
# Out:
#      Unnamed: 0 createDt  deathCnt  decideCnt  seq   stateDt stateTime  \
# 0             0  56:05.3      8058    3134456  803  20220228      0:00
# 1             1  54:59.1      7944    2994830  802  20220227      0:00
# 2             2  10:30.9      7895    2831275  801  20220226      0:00
# 3             3  19:35.5      7783    2665074  800  20220225      0:00
# 4             4  45:42.5      7689    2499187  799  20220224      0:00
# ..          ...      ...       ...        ...  ...       ...       ...
# 715         715  00:00.0        72       8086   55  20200314      0:00
# 716         716  00:00.0        67       7979   54  20200313      0:00
# 717         717  00:00.0        66       7869   53  20200312      0:00
# 718         718  00:00.0        60       7755   52  20200311      0:00
# 719         719  00:00.0        54       7513   51  20200310      0:00
#
#     updateDt  accExamCnt  accDefRate
# 0        NaN         NaN         NaN
# 1    56:31.2         NaN         NaN
# 2    56:10.4         NaN         NaN
# 3    11:20.4         NaN         NaN
# 4    19:57.6         NaN         NaN
# ..       ...         ...         ...
# 715  30:51.5    261335.0    3.318000
# 716  30:51.5    248647.0    3.458499
# 717  30:51.5    234998.0    3.621744
# 718  30:51.5    222395.0    3.804175
# 719  30:51.5    210144.0    3.919308
#
# [720 rows x 10 columns]

# %%
# 데이터프레임의 columns 값을 변경해준다
corona_df.columns=['인덱스','등록일시', '사망자', '확진자', 
'게시글번호', '기준일', '기준시간', '수정일시', 
'누적 의심자', '누적확진률']
corona_df
# Out:
#      인덱스     등록일시   사망자      확진자  게시글번호       기준일  기준시간     수정일시    누적 의심자  \
# 0      0  56:05.3  8058  3134456    803  20220228  0:00      NaN       NaN
# 1      1  54:59.1  7944  2994830    802  20220227  0:00  56:31.2       NaN
# 2      2  10:30.9  7895  2831275    801  20220226  0:00  56:10.4       NaN
# 3      3  19:35.5  7783  2665074    800  20220225  0:00  11:20.4       NaN
# 4      4  45:42.5  7689  2499187    799  20220224  0:00  19:57.6       NaN
# ..   ...      ...   ...      ...    ...       ...   ...      ...       ...
# 715  715  00:00.0    72     8086     55  20200314  0:00  30:51.5  261335.0
# 716  716  00:00.0    67     7979     54  20200313  0:00  30:51.5  248647.0
# 717  717  00:00.0    66     7869     53  20200312  0:00  30:51.5  234998.0
# 718  718  00:00.0    60     7755     52  20200311  0:00  30:51.5  222395.0
# 719  719  00:00.0    54     7513     51  20200310  0:00  30:51.5  210144.0
#
#         누적확진률
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ..        ...
# 715  3.318000
# 716  3.458499
# 717  3.621744
# 718  3.804175
# 719  3.919308
#
# [720 rows x 10 columns]

# %%
corona_df.describe()
# Out:
#               인덱스          사망자           확진자       게시글번호           기준일  \
# count  720.000000   720.000000  7.200000e+02  720.000000  7.200000e+02
# mean   359.500000  1840.476389  2.135333e+05  419.370833  2.020738e+07
# std    207.990384  1842.137253  3.673034e+05  218.672197  6.076163e+03
# min      0.000000    54.000000  7.513000e+03   51.000000  2.020031e+07
# 25%    179.750000   335.500000  2.126525e+04  231.750000  2.020091e+07
# 50%    359.500000  1629.500000  9.183800e+04  411.500000  2.021031e+07
# 75%    539.250000  2294.750000  2.539270e+05  621.250000  2.021090e+07
# max    719.000000  8058.000000  3.134456e+06  803.000000  2.022023e+07
#
#              누적 의심자       누적확진률
# count  6.920000e+02  623.000000
# mean   7.545057e+06    1.556435
# std    6.172020e+06    0.543014
# min    2.101440e+05    0.902205
# 25%    1.934309e+06    1.078089
# 50%    6.368310e+06    1.416159
# 75%    1.216890e+07    1.816009
# max    2.151807e+07    3.919308

# %% [markdown]
# ### describe()는 데이터프레임의 정보를 요약하여 보여준다.
# 1. count : 컬럼별 데이터의 수
# 2. mean : 컬럼별 데이터의 평균
# 3. std : 컬럼별 데이터의 표준편차
# 4. min : 컬럼별 데이터 최소값
# 5. max : 컬럼별 데이터의 최대값
# 6. 25% / 50% / 75% : 백분위수의 각 지점으로, 분포를 반영하여 평균을 보완하는 목적으로 사용

# %%
corona_df['누적확진률'].describe()
# Out:
# count    623.000000
# mean       1.556435
# std        0.543014
# min        0.902205
# 25%        1.078089
# 50%        1.416159
# 75%        1.816009
# max        3.919308
# Name: 누적확진률, dtype: float64

# %%
# Series 형태로 변환
corona_df.사망자
# Out:
# 0      8058
# 1      7944
# 2      7895
# 3      7783
# 4      7689
#        ...
# 715      72
# 716      67
# 717      66
# 718      60
# 719      54
# Name: 사망자, Length: 720, dtype: int64

# %%
corona_df['확진자']
# Out:
# 0      3134456
# 1      2994830
# 2      2831275
# 3      2665074
# 4      2499187
#         ...
# 715       8086
# 716       7979
# 717       7869
# 718       7755
# 719       7513
# Name: 확진자, Length: 720, dtype: int64

# %%
corona_df_2 = corona_df.sort_values("등록일시")
corona_df_2
# Out:
#      인덱스     등록일시   사망자     확진자  게시글번호       기준일  기준시간     수정일시      누적 의심자  \
# 359  359  00:00.0  1632   92047    412  20210306  0:00  30:51.5   6821942.0
# 475  475  00:00.0   485   27652    296  20201110  0:00  30:51.5   2723959.0
# 476  476  00:00.0   480   27552    295  20201109  0:00  30:51.5   2709198.0
# 477  477  00:00.0   478   27426    294  20201108  0:00  30:51.5   2702879.0
# 478  478  00:00.0   477   27283    293  20201107  0:00  30:51.5   2697248.0
# ..   ...      ...   ...     ...    ...       ...   ...      ...         ...
# 33    33  59:34.4  6620  762969    770  20220126  0:00  06:04.5  21110639.0
# 35    35  59:37.8  6565  741390    768  20220124  0:00  06:21.7  20943638.0
# 97    97  59:47.9  3328  420946    706  20211123  0:00  06:13.3  16878955.0
# 63    63  59:50.6  5300  611650    740  20211227  0:00  05:27.2  19082135.0
# 64    64  59:54.2  5245  607447    739  20211226  0:00  59:43.4  19040194.0
#
#         누적확진률
# 359  1.362293
# 475  1.025628
# 476  1.026759
# 477  1.024417
# 478  1.021441
# ..        ...
# 33        NaN
# 35        NaN
# 97   2.787908
# 63        NaN
# 64        NaN
#
# [720 rows x 10 columns]

# %% [markdown]
# ### sort_index(), sort_values()
# 1. sort_index는 데이터프레임을 오름차순 혹은 내림차순으로 정렬
# 1. sort_valeus를 이용하여 해당하는 컬럼의 값을 기준으로 오름차순으로 데이터 정렬
# 2. 내림차순으로 변경을 하고 싶다고 하면 ascending=False 옵션을 사용하면 내림차순으로 정렬

# %%
corona_df_2["일일 확진자"] = (corona_df_2["확진자"] - corona_df_2["확진자"].shift()).fillna(0)
#처음 측정 데이터는 차를 구할 게 없어서 결측값 0으로 대체
#shift()아래 칸
corona_df_2
# Out:
#      인덱스     등록일시   사망자     확진자  게시글번호       기준일  기준시간     수정일시      누적 의심자  \
# 359  359  00:00.0  1632   92047    412  20210306  0:00  30:51.5   6821942.0
# 475  475  00:00.0   485   27652    296  20201110  0:00  30:51.5   2723959.0
# 476  476  00:00.0   480   27552    295  20201109  0:00  30:51.5   2709198.0
# 477  477  00:00.0   478   27426    294  20201108  0:00  30:51.5   2702879.0
# 478  478  00:00.0   477   27283    293  20201107  0:00  30:51.5   2697248.0
# ..   ...      ...   ...     ...    ...       ...   ...      ...         ...
# 33    33  59:34.4  6620  762969    770  20220126  0:00  06:04.5  21110639.0
# 35    35  59:37.8  6565  741390    768  20220124  0:00  06:21.7  20943638.0
# 97    97  59:47.9  3328  420946    706  20211123  0:00  06:13.3  16878955.0
# 63    63  59:50.6  5300  611650    740  20211227  0:00  05:27.2  19082135.0
# 64    64  59:54.2  5245  607447    739  20211226  0:00  59:43.4  19040194.0
#
#         누적확진률    일일 확진자
# 359  1.362293       0.0
# 475  1.025628  -64395.0
# 476  1.026759    -100.0
# 477  1.024417    -126.0
# 478  1.021441    -143.0
# ..        ...       ...
# 33        NaN   79413.0
# 35        NaN  -21579.0
# 97   2.787908 -320444.0
# 63        NaN  190704.0
# 64        NaN   -4203.0
#
# [720 rows x 11 columns]

# %% [markdown]
# ### shift()
# 1. shift()는 colimn을 하나 내리는 함수
# 2. shift(N)은 N개만큼 column를 내린다.
#
# ### fillna()
# 1. fillna()는 값이 NaN인 경우 ()안에 값으로 대체한다.

# %%
corona_df_3 = corona_df.copy().sort_values("등록일시")
#copy(): 원본 파일 복원하고 싶을 때
corona_df_3["일일 확진자"] = corona_df_3["확진자"].diff()
# (corona_df_2["확진자"] - corona_df_2["확진자"].shift())와 동일
corona_df_3
# Out:
#      인덱스     등록일시   사망자     확진자  게시글번호       기준일  기준시간     수정일시      누적 의심자  \
# 359  359  00:00.0  1632   92047    412  20210306  0:00  30:51.5   6821942.0
# 475  475  00:00.0   485   27652    296  20201110  0:00  30:51.5   2723959.0
# 476  476  00:00.0   480   27552    295  20201109  0:00  30:51.5   2709198.0
# 477  477  00:00.0   478   27426    294  20201108  0:00  30:51.5   2702879.0
# 478  478  00:00.0   477   27283    293  20201107  0:00  30:51.5   2697248.0
# ..   ...      ...   ...     ...    ...       ...   ...      ...         ...
# 33    33  59:34.4  6620  762969    770  20220126  0:00  06:04.5  21110639.0
# 35    35  59:37.8  6565  741390    768  20220124  0:00  06:21.7  20943638.0
# 97    97  59:47.9  3328  420946    706  20211123  0:00  06:13.3  16878955.0
# 63    63  59:50.6  5300  611650    740  20211227  0:00  05:27.2  19082135.0
# 64    64  59:54.2  5245  607447    739  20211226  0:00  59:43.4  19040194.0
#
#         누적확진률    일일 확진자
# 359  1.362293       NaN
# 475  1.025628  -64395.0
# 476  1.026759    -100.0
# 477  1.024417    -126.0
# 478  1.021441    -143.0
# ..        ...       ...
# 33        NaN   79413.0
# 35        NaN  -21579.0
# 97   2.787908 -320444.0
# 63        NaN  190704.0
# 64        NaN   -4203.0
#
# [720 rows x 11 columns]

# %%
corona_df_2['일일 확진자'].value_counts()
# Out:
# -39.0      7
# -27.0      5
# -34.0      5
# -61.0      5
# -9.0       3
#           ..
# -267.0     1
# -235.0     1
# -248.0     1
# -299.0     1
# -4203.0    1
# Name: 일일 확진자, Length: 634, dtype: int64

# %% [markdown]
# ### value_counts()
# 1. 컬럼 값의 분포도를 나타낸다. (내림차순)
# 2. sql의 count와 같다고 생각하면 편하다.
# 3. ascending = True 옵션을 추가하면 오름차순으로 변경된다.

# %%
corona_df_4 = corona_df_2.drop(['인덱스', '기준시간', '누적 의심자', '누적확진률', "게시글번호", '수정일시'], axis=1)
# axis=1 은 열 삭제, axis=0 는 행 삭제
corona_df_4
# Out:
#         등록일시   사망자     확진자       기준일    일일 확진자
# 359  00:00.0  1632   92047  20210306       0.0
# 475  00:00.0   485   27652  20201110  -64395.0
# 476  00:00.0   480   27552  20201109    -100.0
# 477  00:00.0   478   27426  20201108    -126.0
# 478  00:00.0   477   27283  20201107    -143.0
# ..       ...   ...     ...       ...       ...
# 33   59:34.4  6620  762969  20220126   79413.0
# 35   59:37.8  6565  741390  20220124  -21579.0
# 97   59:47.9  3328  420946  20211123 -320444.0
# 63   59:50.6  5300  611650  20211227  190704.0
# 64   59:54.2  5245  607447  20211226   -4203.0
#
# [720 rows x 5 columns]

# %%
corona_df_4.reset_index(drop=True, inplace=True)
# drop= True 기존 인덱스 값 삭제
# inplace = True 원본 데이터 수정
# inplace = False로 해놓고 기존 변수에 넣으면 오류 발생
# Out:
#         등록일시   사망자     확진자       기준일    일일 확진자
# 0    00:00.0  1632   92047  20210306       0.0
# 1    00:00.0   485   27652  20201110  -64395.0
# 2    00:00.0   480   27552  20201109    -100.0
# 3    00:00.0   478   27426  20201108    -126.0
# 4    00:00.0   477   27283  20201107    -143.0
# ..       ...   ...     ...       ...       ...
# 715  59:34.4  6620  762969  20220126   79413.0
# 716  59:37.8  6565  741390  20220124  -21579.0
# 717  59:47.9  3328  420946  20211123 -320444.0
# 718  59:50.6  5300  611650  20211227  190704.0
# 719  59:54.2  5245  607447  20211226   -4203.0
#
# [720 rows x 5 columns]

# %% [markdown]
# ### index 초기화
# 1. DataFrame.reset_index()
# 2. level은 index의 주어진 단계를 제거. 기본값은 모든 단계를 제거
# 3. col_level은 멀티인덱스인 경우 어떤 것을 삽입할 것인지 설정
# 4. col_fill은 멀티인덱스인 경우 다른 단계의 이름을 설정
# 5. drop은 기존의 인덱스 값을 삭제할지 여부 설정
# 6. inplace는 원본 객체를 변경할지 여부 설정

# %%
import matplotlib.pyplot as plt

decide_cnt = corona_df_4.head(30)["일일 확진자"].values.tolist()
#tolist는 리스트 형태로 변환
state_dt = corona_df_4.head(30)["등록일시"].values.tolist()

plt.plot(state_dt, decide_cnt)
plt.show()
