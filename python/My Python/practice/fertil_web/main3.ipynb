# %%
import pandas as pd

fertil_df = pd.read_csv('./fertil.csv')

fertil_df
# Out:
#                                         Country Name Country Code  \
# 0                                        Korea, Rep.          KOR
# 1                                              Japan          JPN
# 2                                      United States          USA
# 3                                              China          CHN
# 4                                             France          FRA
# 5                                            Germany          DEU
# 6                                                NaN          NaN
# 7                                                NaN          NaN
# 8                                                NaN          NaN
# 9   Data from database: World Development Indicators          NaN
# 10                          Last Updated: 02/15/2022          NaN
#
#                                  Series Name     Series Code  2006 [YR2006]  \
# 0   Fertility rate, total (births per woman)  SP.DYN.TFRT.IN          1.132
# ...

# %%
fertil_df_2 = fertil_df.drop(['Country Name','Series Name','Series Code','2020 [YR2020]'], axis=1)
fertil_df_2
# Out:
#    Country Code  2006 [YR2006]  2007 [YR2007]  2008 [YR2008]  2009 [YR2009]  \
# 0           KOR          1.132          1.259          1.192          1.149
# 1           JPN          1.320          1.340          1.370          1.370
# 2           USA          2.108          2.120          2.072          2.002
# 3           CHN          1.615          1.617          1.620          1.623
# 4           FRA          2.000          1.980          2.010          2.000
# 5           DEU          1.330          1.370          1.380          1.360
# 6           NaN            NaN            NaN            NaN            NaN
# 7           NaN            NaN            NaN            NaN            NaN
# 8           NaN            NaN            NaN            NaN            NaN
# 9           NaN            NaN            NaN            NaN            NaN
# 10          NaN            NaN            NaN            NaN            NaN
#
# ...
