# %% [markdown]
# 1. 인자값으로 url 주소 받아오기 (csv파일 주소)
# 2. 함수를 하나 생성 -> url에 있는 csv파일을 읽어오고, 'country'기준으로 sort, 인덱스값 초기화
# 3. 함수를 하나 생성 -> 인자값을 리스트로 받는다 -> 이 매개변수를 기준으로 columns 삭제

# %%
import pandas as pd

# %%
class Change_dt():

    
    def __init__(self,input_url):
        self.url = input_url


    def csv_read(self):
        self.dt = pd.read_csv("./csv/Sales Records.csv")
        self.dt.sort_values("Country", inplace=True)
        self.dt.reset_index(drop=True,inplace=True)
        return self.dt
        

    def remove_c(self, input_a):
        self.dt.drop(input_a, axis=1, inplace=True)
        return self.dt


dt = Change_dt("./csv/Sales Records.csv")

# %%
dt.csv_read()
# Out:
#                             Region      Country        Item Type  \
# 0     Middle East and North Africa  Afghanistan           Cereal
# 1     Middle East and North Africa  Afghanistan        Household
# 2     Middle East and North Africa  Afghanistan           Cereal
# 3     Middle East and North Africa  Afghanistan             Meat
# 4     Middle East and North Africa  Afghanistan        Household
# ...                            ...          ...              ...
# 9995            Sub-Saharan Africa     Zimbabwe           Cereal
# 9996            Sub-Saharan Africa     Zimbabwe  Office Supplies
# 9997            Sub-Saharan Africa     Zimbabwe           Fruits
# 9998            Sub-Saharan Africa     Zimbabwe          Clothes
# 9999            Sub-Saharan Africa     Zimbabwe           Fruits
#
#      Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0          Offline              H   7/24/2013  933963477   8/23/2013
# ...

# %%
dt.remove_c(["Item Type","Region"])
# Out:
#           Country Sales Channel Order Priority  Order Date   Order ID  \
# 0     Afghanistan       Offline              H   7/24/2013  933963477
# 1     Afghanistan       Offline              L    2/4/2012  772306096
# 2     Afghanistan       Offline              H   8/20/2015  667230880
# 3     Afghanistan       Offline              H   8/11/2012  161685121
# 4     Afghanistan       Offline              M   3/25/2011  440761888
# ...           ...           ...            ...         ...        ...
# 9995     Zimbabwe        Online              C   1/16/2016  742576920
# 9996     Zimbabwe       Offline              L   1/26/2010  322291505
# 9997     Zimbabwe       Offline              C  11/20/2015  436287105
# 9998     Zimbabwe        Online              C   1/21/2017  433102357
# 9999     Zimbabwe       Offline              C  12/29/2012  486245286
#
#        Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# ...

# %%
import mod1

# %%
mod1.add(5,3)
# Out:
# 8
# 8

# %%
# 폴더로부터 mod2 불러오겠다
from module import mod2

mod2.sub(5,2)
# Out:
# 3
# 3

# %%
from mod3 import add, sub

# %%
import mod4 

dt = mod4.Change_dt_2("./csv/Sales Records.csv")

# %%
#import mod.1
#import imp
#imp.reload(mod.1)

# %%
dt.csv_read()
# Out:
#                             Region      Country        Item Type  \
# 0     Middle East and North Africa  Afghanistan           Cereal
# 1     Middle East and North Africa  Afghanistan        Household
# 2     Middle East and North Africa  Afghanistan           Cereal
# 3     Middle East and North Africa  Afghanistan             Meat
# 4     Middle East and North Africa  Afghanistan        Household
# ...                            ...          ...              ...
# 9995            Sub-Saharan Africa     Zimbabwe           Cereal
# 9996            Sub-Saharan Africa     Zimbabwe  Office Supplies
# 9997            Sub-Saharan Africa     Zimbabwe           Fruits
# 9998            Sub-Saharan Africa     Zimbabwe          Clothes
# 9999            Sub-Saharan Africa     Zimbabwe           Fruits
#
#      Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0          Offline              H   7/24/2013  933963477   8/23/2013
# ...

# %%
dt.remove_c("Item Type")
# Out:
#                             Region      Country Sales Channel Order Priority  \
# 0     Middle East and North Africa  Afghanistan       Offline              H
# 1     Middle East and North Africa  Afghanistan       Offline              L
# 2     Middle East and North Africa  Afghanistan       Offline              H
# 3     Middle East and North Africa  Afghanistan       Offline              H
# 4     Middle East and North Africa  Afghanistan       Offline              M
# ...                            ...          ...           ...            ...
# 9995            Sub-Saharan Africa     Zimbabwe        Online              C
# 9996            Sub-Saharan Africa     Zimbabwe       Offline              L
# 9997            Sub-Saharan Africa     Zimbabwe       Offline              C
# 9998            Sub-Saharan Africa     Zimbabwe        Online              C
# 9999            Sub-Saharan Africa     Zimbabwe       Offline              C
#
# ...

# %%
from mod4 import Change_dt_2 as ct

dt_2 = ct("./csv/Sales Records.csv")

# %%
dt_2.csv_read()
# Out:
#                             Region      Country        Item Type  \
# 0     Middle East and North Africa  Afghanistan           Cereal
# 1     Middle East and North Africa  Afghanistan        Household
# 2     Middle East and North Africa  Afghanistan           Cereal
# 3     Middle East and North Africa  Afghanistan             Meat
# 4     Middle East and North Africa  Afghanistan        Household
# ...                            ...          ...              ...
# 9995            Sub-Saharan Africa     Zimbabwe           Cereal
# 9996            Sub-Saharan Africa     Zimbabwe  Office Supplies
# 9997            Sub-Saharan Africa     Zimbabwe           Fruits
# 9998            Sub-Saharan Africa     Zimbabwe          Clothes
# 9999            Sub-Saharan Africa     Zimbabwe           Fruits
#
#      Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0          Offline              H   7/24/2013  933963477   8/23/2013
# ...

# %%
0.5보다 크면 1
작거나 같으면 0

# %%
import numpy as np

# %%
n_a = np.random.random((10,2))

n_a
# Out:
# array([[0.02621998, 0.39499245],
#        [0.37028981, 0.4273758 ],
#        [0.99418255, 0.93552887],
#        [0.03751827, 0.64265221],
#        [0.77960425, 0.3115555 ],
#        [0.12196583, 0.23805624],
#        [0.58103465, 0.89731246],
#        [0.11782955, 0.80550764],
#        [0.77029323, 0.89136138],
#        [0.42484114, 0.91200425]])

# %%
for i in range(10):
    if n_a[i][1]>0.5:
        n_a[i][1]=1
    else:
        n_a[i][1]=0
n_a
# Out:
# array([[0.02621998, 0.        ],
#        [0.37028981, 0.        ],
#        [0.99418255, 1.        ],
#        [0.03751827, 1.        ],
#        [0.77960425, 0.        ],
#        [0.12196583, 0.        ],
#        [0.58103465, 1.        ],
#        [0.11782955, 1.        ],
#        [0.77029323, 1.        ],
#        [0.42484114, 1.        ]])

# %%
# Out:
#           0    1
# 0  0.026220  0.0
# 1  0.370290  0.0
# 2  0.994183  1.0
# 3  0.037518  1.0
# 4  0.779604  0.0
# 5  0.121966  0.0
# 6  0.581035  1.0
# 7  0.117830  1.0
# 8  0.770293  1.0
# 9  0.424841  1.0

# %%
dt[1].round(0)
# Out:
# 0    0.0
# 1    0.0
# 2    1.0
# 3    1.0
# 4    0.0
# 5    0.0
# 6    1.0
# 7    1.0
# 8    1.0
# 9    1.0
# Name: 1, dtype: float64

# %%
dt[1].apply(lambda x : 1 if (x>0.5) else 0)
# Out:
# 0    0
# 1    0
# 2    1
# 3    1
# 4    0
# 5    0
# 6    1
# 7    1
# 8    1
# 9    1
# Name: 1, dtype: int64

# %%
def _round(x):
    if x > 0.5:
        return 1
    else:
        return 0

dt[1].apply(_round)
# Out:
# 0    0
# 1    0
# 2    1
# 3    1
# 4    0
# 5    0
# 6    1
# 7    1
# 8    1
# 9    1
# Name: 1, dtype: int64

# %%
class Class_1():
    def a(self):
        print("Class_1")

class Class_2():
    def b(self):
        print("Class_2")

class Class_3(Class_2, Class_1):
    def c(self):
        print("Class_3")

x = Class_3()

# %%
x.c()
x.a()
x.b()
# Out:
# Class_3
# Class_1
# Class_2
